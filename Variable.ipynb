# %% [raw]
# # A variable is a name used to store data (value) in memory.
#  # A variable is a container that holds data.
#
# A variable in Python is a name that is used to store data values. Python is dynamically typed, so we do not need to declare the data type explicitly.
#
#    #  a = 10
#    #  name = "Kalyani"
#    #  price = 99.5
#    #  is_active = True
#
#      # Here:-
#        # a         - stores an integer
#        # name      - stores a string
#        # price     - stores a float
#        # is_active - stores a boolean
#
#  Rules for Naming Variables:-
#
#         ✔ Must start with a letter (a-z, A-Z) or underscore _
#         ✔ Cannot start with a number
#         ✔ Can contain letters, numbers, and underscores
#         ✔ Case-sensitive (name and Name are different)

# %%
a, b, c = 10, 20, 30   # Assign multiple values

# %%
a
# Out:
# 10

# %%
a,b,c
# Out:
# (10, 20, 30)

# %%
x = y = z = 100   # Assign same value to multiple variables

# %%
x
# Out:
# 100

# %%
x,y,z
# Out:
# (100, 100, 100)

# %%
x = 10           # int   (Python automatically detects data type.) Python allows changing variable type.
x = "Hello"      # now string
x
# Out:
# 'Hello'

# %%
a = 10                    #Check Variable Type
print(type(a))            # <class 'int'>
# Out:
# <class 'int'>

# %% [raw]
#     ## variable are case sensitive,dose not start with number (1a) but it begeings with the number (a1),
#     ## and not allowed to define special charecter

# %%
a1 = 55
a1
# Out:
# 55

# %%
x_train,x_test, y_train,y_test= 80,20,20,10

# %%
x_train
# Out:
# 80

# %%
x_test
y_train
# Out:
# 20

# %%
x_train
x_test
y_train
y_test

print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
# 80
# 20
# 20
# 10

# %%
first_name = 'Kalyani'
last_name = 'ZADE'
country = 'HYD'
city = 'TELENGANA'
age = 40087
is_married = True
skills = ['HTML', 'CSS', 'JS', 'React', 'Python']
person_info = {
    'firstname':'Rakesh', 
    'lastname':'Pawade', 
    'country':'Finland',
    'city':'Helsinki'
    }

# %%
city
# Out:
# 'TELENGANA'

# %%
person_info
# Out:
# {'firstname': 'Rakesh',
#  'lastname': 'Pawade',
#  'country': 'Finland',
#  'city': 'Helsinki'}

# %%
print('First name:', first_name)
print('First name length:', len(first_name))
print('Last name: ', last_name)
print('Last name length: ', len(last_name))
print('Country: ', country)
print('City: ', city)
print('Age: ', age)
print('Married: ', is_married)
print('Skills: ', skills)
print('Person information: ', person_info)
# Out:
# First name: Kalyani
# First name length: 7
# Last name:  ZADE
# Last name length:  4
# Country:  HYD
# City:  TELENGANA
# Age:  40087
# Married:  True
# Skills:  ['HTML', 'CSS', 'JS', 'React', 'Python']
# Person information:  {'firstname': 'Rakesh', 'lastname': 'Pawade', 'country': 'Finland', 'city': 'Helsinki'}

# %%
first_name, last_name, country, age, is_married = 'chiu', 'Rakesh', 'KALYANI', 250, True

# Declaring multiple variables in one line

# %%
print(first_name, last_name, country, age, is_married)
print('First name:', first_name)
print('Last name: ', last_name)
print('Country: ', country)
print('Age: ', age)
print('Married: ', is_married)
# Out:
# chiu Rakesh KALYANI 250 True
# First name: chiu
# Last name:  Rakesh
# Country:  KALYANI
# Age:  250
# Married:  True
