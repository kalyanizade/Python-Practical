# %% [markdown]
# ## Python Function

# %% [markdown]
# ##  User-defined Functions

# %%
# In Python, a function is a reusable block of code that performs a specific task.
# Functions created by the user using def.

# %%
def greet():
    print('hello')
    print('good morning')

# %%
def greet():
    print('hello')
    print('good morning')
greet()
# Out:
# hello
# good morning

# %%
def greet():
    print('hello')
    print('good morning')
greet()

print('**************')

greet()

print('#############')
# Out:
# hello
# good morning
# **************
# hello
# good morning
# #############

# %%
def multiply(a, b):
    return a * b

print(multiply(3, 4))  # 12
# Out:
# 12

# %% [markdown]
# # Function with No Arguments (without argument)
#
# ## No input is passed.

# %%
def greet():
    print("Hello!")

greet()
# Out:
# Hello!

# %%
def greet():
    print('hello')
    print('good morning')
greet()

def add(x,y):
    c=x+y
    print(c)
add(5,6)
# Out:
# hello
# good morning
# 11

# %%
# function argument - we need to mentain at def fun place 
# actual argument - we need to call at call fun place 
# formanl argu ==  actual argu

# %%
def add(x,y):
    c=x+y
    return(c)
add(5,4)
# Out:
# 9

# %%
def sub(x,y,z):
    c=x+y+z
    return(c)
sub(1,4,5)
# Out:
# 10

# %%
def greet():
    print('hello')
    print('good morning')
    
def add(x,y):
    c=x+y
    return(c)

def sub(x,y,z):
    d=x+y+z
    return(d)

greet()
add(5,4)
sub(1,4,5)
# Out:
# hello
# good morning
# 10

# %%
def greet():
    print('hello')
    print('good morning')
    
def add_sub(x,y):
    c=x+y
    d=x-y
    return c,d
    
greet()
add_sub(5,4)
# Out:
# hello
# good morning
# (9, 1)

# %%
def add_sub(x,y):
    c=x+y
    d=x-y
    return c,d

res1,res2 = add_sub(5,4)

print(res1,res2)

print(type(res1))
print(type(res2))
# Out:
# 9 1
# <class 'int'>
# <class 'int'>

# %%
# 1. Positional Arguments

# Arguments are passed in the correct order.

def add(a, b):
    return a + b

print(add(2, 3))  # 5
# Out:
# 5

# %%
# 2. Keyword Arguments

# Arguments are passed using parameter names.

def student(name, age):
    print(name, age)

student(age=22, name="Kalyani")

# 👉 Order does NOT matter.
# Out:
# Kalyani 22

# %%
# 3. Default Arguments

# You can assign default values to parameters.

def greet(name="Guest"):
    print("Hello", name)

greet()           # Hello Guest
greet("Kalyani")  # Hello Kalyani
# Out:
# Hello Guest
# Hello Kalyani

# %%
# 4. Variable-length Arguments (*args)

# Used when you don’t know how many arguments will be passed.

def total(*numbers):
    return sum(numbers)

print(total(1, 2, 3))      # 6
print(total(1, 2, 3, 4))   # 10

# 👉 *args collects values as a tuple.
# Out:
# 6
# 10

# %%
# 5. Keyword Variable-length Arguments (**kwargs)

# Used to pass multiple keyword arguments.

def details(**data):
    print(data)

details(name="Kalyani", age=22)

# 👉 **kwargs collects values as a dictionary.
# Out:
# {'name': 'Kalyani', 'age': 22}

# %%
# 6. Mixed Arguments

# You can combine different types (but follow order rules).

def func(a, b=10, *args, **kwargs):
    print(a, b, args, kwargs)

func(1, 2, 3, 4, x=5, y=6)
# Out:
# 1 2 (3, 4) {'x': 5, 'y': 6}

# %%
#🔥 Important Order Rule:
# def func(positional, default=10, *args, **kwargs):
#    pass

# Order must be:

# Positional
# Default
# *args
# **kwargs
