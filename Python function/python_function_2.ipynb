# %%
def greet():
    print('hello')
    print('good morning')

# %%
def greet():
    print('hello')
    print('good morning')
greet()
# Out:
# hello
# good morning

# %%
def greet():
    print('hello')
    print('good morning')
greet()

def greet():
    print('hello')
    print('good morning')
greet()
# Out:
# hello
# good morning
# hello
# good morning

# %%
def greet():
    print('hello')
    print('good morning')
greet()

print()

greet()
# Out:
# hello
# good morning
#
# hello
# good morning

# %%
def greet():
    print('hello')
    print('good morning')
greet()

print('*******************')

greet()

print('############')
# Out:
# hello
# good morning
# *******************
# hello
# good morning
# ############

# %% [markdown]
# # define the function without argument

# %%
def add(x,y):
    c=x+y
    print(c)  
add(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2     c=x+y
#       3     print(c)
# ----> 4 add(5)
#
# TypeError: add() missing 1 required positional argument: 'y'

# %%
def add(x,y):
    c=x+y
    print(c)  
add(5,6,7,8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       2     c=x+y
#       3     print(c)
# ----> 4 add(5,6,7,8)
#
# TypeError: add() takes 2 positional arguments but 4 were given

# %%
def add(x,y):
    c=x+y
    print(c)  
add(5,'a')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2     c=x+y
#       3     print(c)
# ----> 4 add(5,'a')
#
# Cell In[9], line 2, in add(x, y)
#       1 def add(x,y):
# ----> 2     c=x+y
#       3     print(c)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
def add(x,y):
    c=x+y
    print(c)  
add(5,4)
# Out:
# 9

# %%
def greet():
    print('hello')
    print('good morning')
greet()

def add(x,y):
    c=x+y
    print(c)  
add(5,4)
# Out:
# hello
# good morning
# 9

# %%
def greet():
    print('hello')
    print('good morning')
def add(x,y):
    c=x+y
    print(c)  

greet()
print('-----')
add(5,4)
# Out:
# hello
# good morning
# -----
# 9

# %%
def add(x,y):
    c=x+y
    print(c)  
add(5,4)
# Out:
# 9

# %%
def add(x,y):
    c=x+y
    return c  
add(5,4)
# Out:
# 9

# %%
def add(x,y,z):
    c=x+y+z
    print(c)  
add(1,4,5)
# Out:
# 10

# %%
def greet():
    print('hello')
    print('good noon')
    
def add(x,y):
    c=x+y
    return c

def sub(x,y):
    d = x-y
    return d
    
greet()    
add(5,4)
sub(10,2)
# Out:
# hello
# good noon
# 8

# %%
def greet():
    print('hello')
    print('good noon')
    
def add_sub(x,y):
    c=x+y
    d=x-y
    return c,d

greet()    
add_sub(5,4)
# Out:
# hello
# good noon
# (9, 1)

# %%
def add_sub(x,y): # what if i want to return 2 values add_sub & i want to return 2 values & function can accept multiple value 
    c= x+y
    d= x-y
    return c, d
    
result = add_sub(4,5)

print(result)
print(type(result))
# Out:
# (9, -1)
# <class 'tuple'>

# %%
def add_sub(x,y):
    c= x+y
    d= x-y
    return c, d

res1,res2 = add_sub(5,4)

print(res1,res2)

print(type(res1))
print(type(res2))
# Out:
# 9 1
# <class 'int'>
# <class 'int'>

# %% [markdown]
# # Update Variable

# %%
def update(): 
    x = 8
    print(x)
update()
# Out:
# 8

# %%
def update(): #update function take the value from the user
    x = 8
    print(x)
update(8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 4
#       2     x = 8
#       3     print(x)
# ----> 4 update(8)
#
# TypeError: update() takes 0 positional arguments but 1 was given

# %%
def update(x): #update function take the value from the user
    x = 8
    return x
    
update(10)
# Out:
# 8

# %%
def update(x): #update function take the value from the user
    x = 8
    return x

a = 10
update(a)
print(a)
# Out:
# 10

# %% [markdown]
# # function argument
# - 1]formal argu ( we define at def() first)
#
# - 2]actual argu (positional , keyword , default ,variable length , kwargs (keyword + variable length))

# %%
def add(a,b): # a & b called formal argument
    c = a+b
    print(c)
    
add(5,6) #5 and 6 we called as actual argument
# Out:
# 11

# %%
def add(a,b): # a & b called formal argument
    c = a+b
    print(c)
    
add(5,6,7) #5 and 6 we called as actual argument
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 5
#       2     c = a+b
#       3     print(c)
# ----> 5 add(5,6,7) #5 and 6 we called as actual argument
#
# TypeError: add() takes 2 positional arguments but 3 were given

# %%
def add(a,b): # a & b called formal argument
    c = a+b
    print(c)
    
add(5) #5 and 6 we called as actual argument
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 5
#       2     c = a+b
#       3     print(c)
# ----> 5 add(5) #5 and 6 we called as actual argument
#
# TypeError: add() missing 1 required positional argument: 'b'

# %%
def person(name,age):
    print(name)
    print(age)
    
person('nit', 22)
# Out:
# nit
# 22

# %%
def person(name,age):
    print(name)
    print(age)
    
person('nit')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 5
#       2     print(name)
#       3     print(age)
# ----> 5 person('nit')
#
# TypeError: person() missing 1 required positional argument: 'age'

# %%
def person(name, age):
    print(name)
    print(age)
    
person(22, 'nit')
# Out:
# 22
# nit

# %%
def person(name, age):
    print(name)
    print(age-5)
    
person(22, 'nit')
# Out:
# 22
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 5
#       2     print(name)
#       3     print(age-5)
# ----> 5 person(22, 'nit')
#
# Cell In[30], line 3, in person(name, age)
#       1 def person(name, age):
#       2     print(name)
# ----> 3     print(age-5)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %% [markdown]
# # keyword argument

# %%
def person(name, age):
    print(name)
    print(age-5)
    
person(age = 22, name = 'nit')
# Out:
# nit
# 17

# %%
def person(name, age, mob):
    print(name)
    print(age-5)
    
person(age = 22, name = 'nit' )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 5
#       2     print(name)
#       3     print(age-5)
# ----> 5 person(age = 22, name = 'nit' )
#
# TypeError: person() missing 1 required positional argument: 'mob'

# %%
def person(name, age, mob):
    print(name)
    print(age-5)
    print(mob)
    
person(age = 22, name = 'nit', mob = 101)
# Out:
# nit
# 17
# 101

# %%
def person(name, age=18):
    print(name)
    print(age)
    
person('nit')
# Out:
# nit
# 18

# %%
def person(name, age=18):
    print(name)
    print(age)
    
person('nit', 40)
# Out:
# nit
# 40
