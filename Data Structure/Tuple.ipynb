# %% [markdown]
# ## Tuple

# %%
# A tuple is a collection data type used to store multiple values in a single variable.
# A tuple is like a list, but it cannot be changed (immutable).
# Use round brackets ( )

#A tuple in Python is an ordered, immutable collection of elements. It allows duplicate values and is defined using parentheses.


        #🔹 Important Properties
                #✔ Ordered
                #✔ Immutable (cannot change)
                #✔ Allows duplicate values
                #✔ Faster than list

        # Tuples have only 2 methods:

            # | Method    | Description        |
            #| --------- | ------------------ |
            #| `count()` | Counts occurrences |
            #| `index()` | Returns index      |


        # 🔹 Difference Between List and Tuple

            # | Feature     | List     |      Tuple              |
        #--------------------------------------------------------
            # | Brackets   |    []    |    ()                    |
            #| Mutable    | ✅ Yes   |    ❌ No                 |
            #| Speed      |  Slower  |     Faster                |
            #| Methods    |  Many    t|   Only 2 (index & count) |

# %% [markdown]
# ## tuple creation

# %%
tup1=()

# %%
tup1
# Out:
# ()

# %%
tup2 = (10,20,30)  # tuple of integers number

# %%
tup2
# Out:
# (10, 20, 30)

# %%
tup3 = (10.77, 30.66 , 60.89)   # tuple of float numbers

# %%
tup3
# Out:
# (10.77, 30.66, 60.89)

# %%
tup4 = ('one','two',"three") # tuple of string

# %%
tup4
# Out:
# ('one', 'two', 'three')

# %%
tup5 = ('Kalyani', 25 , (50,100),(150,90)) # nested tuple

# %%
tup5
# Out:
# ('Kalyani', 25, (50, 100), (150, 90))

# %%
tup6 = (100,'kalyani',17.765)   # tuple of mix data type

# %%
tup6
# Out:
# (100, 'kalyani', 17.765)

# %%
tup7 = ('kalyani',25,[50,100],[150,90],{'john','chiu'},(99,22,33))

# %%
tup7
# Out:
# ('kalyani', 25, [50, 100], [150, 90], {'chiu', 'john'}, (99, 22, 33))

# %%
len(tup7)   # length of list
# Out:
# 6

# %% [markdown]
# ## Tuple Indexing

# %%
tup2
# Out:
# (10, 20, 30)

# %%
tup2[0]  # retrive first element of the tuple
# Out:
# 10

# %%
tup4
# Out:
# ('one', 'two', 'three')

# %%
tup4[0]  # retrive first element of the tuple
# Out:
# 'one'

# %%
tup4
# Out:
# ('one', 'two', 'three')

# %%
tup4[0][0]   # nested indexing - access the first charecter of the first tuple element
# Out:
# 'o'

# %%
tup4[-1]    # last item of the tuple
# Out:
# 'three'

# %%
tup5
# Out:
# ('Kalyani', 25, (50, 100), (150, 90))

# %%
tup5[-1]   # last item of the tuple
# Out:
# (150, 90)

# %% [markdown]
# ## Tuple Slicing

# %%
mytuple = ('one','two','three','four','five','six','seven','eight')

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytuple[0:3]   # Return all items from 0th to 3rd index location excluding the item
# Out:
# ('one', 'two', 'three')

# %%
mytuple[2:5] # list all items from 2th to 35th index location excluding the item
# Out:
# ('three', 'four', 'five')

# %%
mytuple[:3] # return first three items
# Out:
# ('one', 'two', 'three')

# %%
mytuple[:2]  # return first two items
# Out:
# ('one', 'two')

# %%
mytuple[-3:] # return last three items
# Out:
# ('six', 'seven', 'eight')

# %%
mytuple[-2:]   # return last two items
# Out:
# ('seven', 'eight')

# %%
mytuple[-1]    # return last item of tuple
# Out:
# 'eight'

# %%
mytuple[:]     # return whole tuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %% [markdown]
# ## Remove & Change items

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
del mytuple[0] # tuple are immutable which means we cant DELETE tuple items
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 del mytuple[0] # tuple are immutable which means we cant DELETE tuple items
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
mytuple[0]=1  # tuple are immutable which means we cant CHANGE tuple items
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 mytuple[0]=1  # tuple are immutable which means we cant CHANGE tuple items
#
# TypeError: 'tuple' object does not support item assignment

# %%
del mytuple  # deleting entire tuple object is possible

# %% [markdown]
# ## Loop through a Tuple

# %%
mytuple = ('one','two','three','four','five','six','seven','eight')

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
for i in mytuple:
    print (i)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight

# %%
for i in enumerate(mytuple):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')
# (7, 'eight')

# %% [markdown]
# ## Tuple Membership

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
'one' in mytuple  # check if 'one' exist in the list
# Out:
# True

# %%
'ten' in mytuple  # check if 'ten' exist in the list
# Out:
# False

# %%
if 'three' in mytuple:   # check if 'three' exist in the list
   print ('three is present in tuple')
else: 
    print('three is not present in the tuple')
# Out:
# three is present in tuple

# %%
if 'eleven' in mytuple:   # check if 'eleven' exist in the list
   print ('eleven is present in tuple')
else: 
    print('eleven is not present in the tuple')
# Out:
# eleven is not present in the tuple

# %% [markdown]
# ## Index Position

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytuple.index('one')  # index of first element equal to 'one'
# Out:
# 0

# %%
mytuple.index('five')  # index of first element equal to 'five'
# Out:
# 4

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytuple.index('one')  # index of first element equal to 'one'
# Out:
# 0

# %% [markdown]
# ## Sorting

# %%
mytuple2 = (43,67,99,12,6,90,67)

# %%
mytuple2
# Out:
# (43, 67, 99, 12, 6, 90, 67)

# %%
sorted(mytuple2)  # returns a new sorted list and dosent  change original tuple
# Out:
# [6, 12, 43, 67, 67, 90, 99]

# %%
sorted(mytuple2 , reverse= True)  # sort in descending order
# Out:
# [99, 90, 67, 67, 43, 12, 6]
