# %%
#  (A data structure is a way to store and organize data so it can be used efficiently.)¶
      #  Data structures help us store multiple values in one variable.
      #  Data structures in Python are used to store and organize data efficiently. 
      #  The main built-in data structures are List, Tuple, Set, and Dictionary.
    
       # data type :- a=2
       # data structure :- a= 1,2.3 , True  ( collection of data type)
       # matrix :-  ( collection of data structure)

# %% [markdown]
#  ##  Main Data Structures in Python
#               # Python has 4 built-in data structures:
#                     # List
#                     # Tuple
#                     # Set
#                     # Dictionary

# %%
    # |  Data Structure  |  Ordered   |  Mutable   |  Duplicates   |
    #   --------------     -------      -------       ----------     
    # | List            |   ✅ Yes   |  ✅ Yes   |   ✅ Yes      |
    # | Tuple           |   ✅ Yes   |  ❌ No    |   ✅ Yes      |
    # | Set             |  ❌ No    |  ✅ Yes    |   ❌ No       |
    # | Dictionary     |  ✅ Yes    |   ✅ Yes   |   Keys ❌     |

# %%
# Diff betn:= 
            
            #  |   Feature           | List  | Tuple    | Set      |       Dict        |
            # ------------------------------------------------------------------------------ 
            #  |  Ordered           | ✅    |  ✅     |   ❌     |     ✅            |
            #  |  Mutable           | ✅    |  ❌     |   ✅     |    ✅             |
            #  |  Allows Duplicates | ✅    |  ✅     |   ❌     |   Keys ❌        |
            #  |  Indexed           | ✅    |  ✅     |   ❌    |    By key         |
            #  |  Syntax            | `[]`  | `()`    |   `{}`   | ` {key:value}`    |

# %% [markdown]
# ## Datastruture - user will define the value more then one

# %%
l = []
l
# Out:
# []

# %%
len(l)
# Out:
# 0

# %%
l.append(10)
l
# Out:
# [10]

# %%
len(l)
# Out:
# 1

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(40)

l
# Out:
# [10, 20, 30, 40, 40]

# %%
len(l)
# Out:
# 5

# %%
l
# Out:
# [10, 20, 30, 40, 40]

# %%
id(l)
# Out:
# 1716263068096

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
a = True
type(a)
# Out:
# bool

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
l
# Out:
# [10, 20, 30, 40, 40]

# %%
l[:]
# Out:
# [10, 20, 30, 40, 40]

# %%
l[0]
# Out:
# 10

# %%
l[1]
# Out:
# 20

# %%
l[-3]
# Out:
# 30

# %%
l
# Out:
# [10, 20, 30, 40, 40]

# %%
l1 = l.copy()
l1
# Out:
# [10, 20, 30, 40, 40]

# %%
l == l1
# Out:
# True

# %%
print(len(l))
print(len(l1))
# Out:
# 5
# 5

# %%
l1
# Out:
# [10, 20, 30, 40, 40]

# %%
l1.append(2.3)
l1.append(True)
l1.append(1+2j)

# %%
l1
# Out:
# [10, 20, 30, 40, 40, 2.3, True, (1+2j)]

# %%
l1.append(50)
l1
# Out:
# [10, 20, 30, 40, 40, 2.3, True, (1+2j), 50]

# %%
l
# Out:
# [10, 20, 30, 40, 40]

# %%
l.count(10)
# Out:
# 1

# %%
l.count(40)
# Out:
# 2

# %%
l
# Out:
# [10, 20, 30, 40, 40]

# %%
l.count(100)
# Out:
# 0

# %%
l
# Out:
# [10, 20, 30, 40, 40]

# %%
l1
# Out:
# [10, 20, 30, 40, 40, 2.3, True, (1+2j), 50]

# %%
l2 = l1.copy()

# %%
l2
# Out:
# [10, 20, 30, 40, 40, 2.3, True, (1+2j), 50]

# %%
l2.remove(True)

# %%
l2
# Out:
# [10, 20, 30, 40, 40, 2.3, (1+2j), 50]

# %%
l2.remove(1+2j)
l2
# Out:
# [10, 20, 30, 40, 40, 2.3, 50]

# %%
l2
# Out:
# [10, 20, 30, 40, 40, 2.3, 50]

# %%
l2.clear()

# %%
l2
# Out:
# []

# %%
del l2       # l2 delete

# %% [markdown]
# ## List

# %%
            #   | Method    | Purpose                  |
            # ------------- ----------------------------
            #  | append()  | Add single element       |
            #  | extend()  | Add multiple elements    |
            #  | insert()  | Add at specific position |
            #  | remove()  | Remove by value          |
            #  | pop()     | Remove by index          |
            #  | clear()   | Remove all               |
            #  | index()   | Find position            |
            #  | count()   | Count occurrences        |
            #  | sort()    | Sort list                |
            #  | reverse() | Reverse list             |
            #  | copy()    | Copy list                |

# %%
    # 1) List is an ordered sequence of items. 
    # 2) We can have different data types under a list. E.g we can have integer, float and string items in a same list.

# %%
l = []
l
# Out:
# []

# %%
list1 = [] # Empty List

# %%
list1
# Out:
# []

# %%
print(type(list1))
# Out:
# <class 'list'>

# %%
len(l)
# Out:
# 0

# %%
list2 = [10,30,60]     # List of integers numbers 
list2
# Out:
# [10, 30, 60]

# %%
list3 = [10.77,30.66,60.89]       # List of float numbers 
list3
# Out:
# [10.77, 30.66, 60.89]

# %%
list4 = ['one','two' , "three"]     # List of strings 
list4
# Out:
# ['one', 'two', 'three']

# %%
list5 = ['kalyani', 25 ,[50, 100],[150, 90]]       # Nested Lists 
list5
# Out:
# ['kalyani', 25, [50, 100], [150, 90]]

# %%
list6 = [100, 'kalyani', 17.765]         # List of mixed data types 
list6
# Out:
# [100, 'kalyani', 17.765]

# %%
len(list6)      #Length of list
# Out:
# 3

# %%
list7 = ['kalyani', 25 ,[50, 100],[150, 90] , {'John' , 'David'},1+2j] 
list7
# Out:
# ['kalyani', 25, [50, 100], [150, 90], {'David', 'John'}, (1+2j)]

# %% [markdown]
# ## List Indexing

# %%
len(list7)      #Length of list
# Out:
# 6

# %%
list7[4]      # Retreive first element of the list
# Out:
# {'David', 'John'}

# %%
list2
# Out:
# [10, 30, 60]

# %%
list2[0]      # Retreive first element of the list
# Out:
# 10

# %%
list4
# Out:
# ['one', 'two', 'three']

# %%
list4[0]        # Retreive first element of the list
# Out:
# 'one'

# %%
list4[0][2]         # Nested indexing - Access the first character of the first list ele
# Out:
# 'e'

# %%
list4[-1]             # Last item of the list
# Out:
# 'three'

# %%
list5[-1]                # Last item of the list
# Out:
# [150, 90]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 40]
# [10, 20, 30, 40, 40, 2.3, True, (1+2j), 50]

# %%
print(len(l))
print(len(l1))
# Out:
# 5
# 9

# %%
l
# Out:
# [10, 20, 30, 40, 40]

# %%
for i in l:
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 40

# %%
l.append([1,2,3,'hi'])                      # nested list 
l
# Out:
# [10, 20, 30, 40, 40, [1, 2, 3, 'hi']]

# %%
l
# Out:
# [10, 20, 30, 40, 40, [1, 2, 3, 'hi']]

# %%
l.remove(40)        #     remove the element

# %%
l
# Out:
# [10, 20, 30, [1, 2, 3, 'hi']]

# %%
l.pop()
# Out:
# [1, 2, 3, 'hi']

# %%
l
# Out:
# [10, 20, 30]

# %%
l1
# Out:
# [10, 20, 30, 40, 40, 2.3, True, (1+2j), 50]

# %%
l1.pop()  #  remove last element
# Out:
# 2.3

# %%
l1
# Out:
# [10, 20, 30, 40, 40]

# %%
l1.pop()
# Out:
# 40

# %%
l1
# Out:
# [10, 20, 30, 40]

# %%
l1.pop(-1)
# Out:
# 40

# %%
l1
# Out:
# [10, 20, 30]

# %%
l1
# Out:
# [10, 20, 30]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30]
# [10, 20, 30]

# %%
l1.append([2.3])                      # nested list 
l1
# Out:
# [10, 20, 30, [2.3]]

# %%
l
# Out:
# [10, 20, 30]

# %%
l1
# Out:
# [10, 20, 30, [2.3]]

# %%
l.insert(35,3)

# %%
l = []
l
# Out:
# []

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(40)

l
# Out:
# [20, 30, 40, 40]

# %%
l1=[]
l1
# Out:
# []

# %%
l1.append(2.3)
l1.append(True)
l1.append(1+2j)

# %%
l1
# Out:
# [2.3, True, (1+2j)]

# %%
l1.append(50)
l1
# Out:
# [2.3, True, (1+2j), 50]

# %%
l2=l1.copy()

# %%
l2
# Out:
# [2.3, True, (1+2j), 50]

# %%
l1.insert(1, 15)

# %%
l1
# Out:
# [2.3, 15, True, (1+2j), 50]

# %%
l3=[]

# %%
l3
# Out:
# []

# %%
l2.extend(l1)

# %%
l2
# Out:
# [2.3, True, (1+2j), 50, 2.3, 15, True, (1+2j), 50]

# %%
l
# Out:
# [20, 30, 40, 40]

# %%
l1
# Out:
# [2.3, 15, True, (1+2j), 50]

# %%
l.extend(l1)

# %%
l
# Out:
# [20, 30, 40, 40, 2.3, 15, True, (1+2j), 50]

# %%
print(l)
# Out:
# [20, 30, 40, 40, 2.3, 15, True, (1+2j), 50]

# %%
print(l1)
# Out:
# [2.3, 15, True, (1+2j), 50]

# %%
print(l2)
# Out:
# [2.3, True, (1+2j), 50, 2.3, 15, True, (1+2j), 50]

# %%
l2.index(50)
# Out:
# 3

# %%
l
# Out:
# [20, 30, 40, 40, 2.3, 15, True, (1+2j), 50]

# %%
l.index(30)
# Out:
# 1

# %%
l
# Out:
# [20, 30, 40, 40, 2.3, 15, True, (1+2j), 50]

# %%
l1
# Out:
# [2.3, 15, True, (1+2j), 50]

# %%
l1
# Out:
# [True, 2.3, 15, 50]

# %%
l1.sort()

# %%
l1
# Out:
# [True, 2.3, 15, 50]

# %%
l1.sort(reverse=True) #descending order

# %%
l1
# Out:
# [50, 15, 2.3, True]

# %%
l3 = [3, 100, 4]
l3
# Out:
# [3, 100, 4]

# %%
l3.sort()

# %%
l3
# Out:
# [3, 4, 100]

# %%
l3.sort(reverse = True)

# %%
l3
# Out:
# [100, 4, 3]

# %%
l6 = [3, 5.6, 'a', 1+2j]

# %%
l6  # l6 is not sort give error because of complex value is there
# Out:
# [3, 5.6, 'a', (1+2j)]

# %%
l5 = ['z', 'm', 'n', 'b']
l5
# Out:
# ['z', 'm', 'n', 'b']

# %%
l5.sort()

# %%
l5
# Out:
# ['b', 'm', 'n', 'z']

# %%
l1.reverse()

# %%
l1
# Out:
# [True, 2.3, 15, 50]

# %%
l1
# Out:
# [True, 2.3, 15, 50]

# %%
l
# Out:
# [20, 30, 40, 40, 2.3, 15, True, (1+2j), 50]

# %%
l[::-1]         # [start : stop : step ] [: :-1]
# Out:
# [50, (1+2j), True, 15, 2.3, 40, 40, 30, 20]

# %%
print(l)
print(l1)
print(l2)
# Out:
# [20, 30, 40, 40, 2.3, 15, True, (1+2j), 50]
# [True, 2.3, 15, 50]
# [2.3, True, (1+2j), 50, 2.3, 15, True, (1+2j), 50]

# %% [markdown]
#  ## String list slicing (data type)

# %%
s1 = 'nit'
s1
# Out:
# 'nit'

# %%
s1[0]
# Out:
# 'n'

# %%
s1[2]
# Out:
# 't'

# %%
s1
# Out:
# 'nit'

# %%
for i in s1:
    print(i)
# Out:
# n
# i
# t

# %% [markdown]
# ##  list slicing = :   list is mutable ( we can change any index)

# %%
   #  [:]->        entire element 
   #  [2:10] ->    print the element from 2nd index to n-1 mens(9th index) 
   #  [:10] ->     print the element from staring to n-1(9th index) 
   #  [3:] ->      print the element from 3rd index to last index 
   #  [1:100:10]-> print the element from start & last index(100th) &step size(10)

# %%
print(l)
# Out:
# [20, 30, 40, 40, 2.3, 15, True, (1+2j), 50]

# %%
l[:]
# Out:
# [20, 30, 40, 40, 2.3, 15, True, (1+2j), 50]

# %%
l[0:8]
# Out:
# [20, 30, 40, 40, 2.3, 15, True, (1+2j)]

# %%
l
# Out:
# [20, 30, 40, 40, 2.3, 15, True, (1+2j), 50]

# %%
l[3:]
# Out:
# [40, 2.3, 15, True, (1+2j), 50]

# %%
l
# Out:
# [20, 30, 40, 40, 2.3, 15, True, (1+2j), 50]

# %%
l[:7]  # stop in 7 the n-1 rule
# Out:
# [20, 30, 40, 40, 2.3, 15, True]

# %%
l
# Out:
# [20, 30, 40, 40, 2.3, 15, True, (1+2j), 50]

# %%
l[0:20:5]
# Out:
# [20, 15]

# %%
l
# Out:
# [20, 30, 40, 40, 2.3, 15, True, (1+2j), 50]

# %%
l[3:10:3]
# Out:
# [40, True]

# %%
l
# Out:
# [20, 30, 40, 40, 2.3, 15, True, (1+2j), 50]

# %%
l[::-1]
# Out:
# [50, (1+2j), True, 15, 2.3, 40, 40, 30, 20]

# %%
l
# Out:
# [20, 30, 40, 40, 2.3, 15, True, (1+2j), 50]

# %%
l[::-2]
# Out:
# [50, True, 2.3, 40, 20]

# %%
l
# Out:
# [20, 30, 40, 40, 2.3, 15, True, (1+2j), 50]

# %%
l[::-3]
# Out:
# [50, 15, 40]

# %%
l1
# Out:
# [True, 2.3, 15, 50]

# %%
l1[0]
# Out:
# True

# %%
l1[0] =  45

# %%
l1
# Out:
# [45, 2.3, 15, 50]

# %%
l1
# Out:
# [45, 2.3, 15, 50]

# %%
l1[-1] = 'nit'

# %%
l1
# Out:
# [45, 2.3, 15, 'nit']

# %%
l1[-1][0]         # nested slicing
# Out:
# 'n'

# %%
l1
# Out:
# [45, 2.3, 15, 'nit']

# %%
print(l1[-1][0])
print(l1[-1][1])
print(l1[-1][2])
# Out:
# n
# i
# t

# %%
l1
# Out:
# [45, 2.3, 15, 'nit']

# %%
l2
# Out:
# [2.3, True, (1+2j), 50, 2.3, 15, True, (1+2j), 50]

# %%
len(l2)
# Out:
# 9

# %%
l3
# Out:
# [100, 4, 3]

# %%
l4 = l2 + l3

# %%
l4
# Out:
# [2.3, True, (1+2j), 50, 2.3, 15, True, (1+2j), 50, 100, 4, 3]

# %%
 # list membership

# %%
l4
# Out:
# [2.3, True, (1+2j), 50, 2.3, 15, True, (1+2j), 50, 100, 4, 3]

# %%
15 in l4
# Out:
# True

# %% [markdown]
# ## ENumerate

# %%
l1
# Out:
# [45, 2.3, 15, 'nit']

# %%
for i in l1:
 print(i)
# Out:
# 45
# 2.3
# 15
# nit

# %%
for i in enumerate(l1):
    print (i)
# Out:
# (0, 45)
# (1, 2.3)
# (2, 15)
# (3, 'nit')

# %%
l1
# Out:
# [45, 2.3, 15, 'nit']

# %%
l3
# Out:
# [100, 4, 3]

# %%
all(l3)
# Out:
# True

# %%
any(l3)
# Out:
# True

# %%
all(l3)
# Out:
# True

# %%
any(l3)
# Out:
# True

# %%
l3.append(0)
l3
# Out:
# [100, 4, 3, 0]

# %%
all(l3)   # if element u have 0 it will give false ( All elements must be True)
# Out:
# False

# %%
any(l3)   # At least one element must be True
# Out:
# True

# %%
fruits = ["apple", "banana", "mango"]

for index, value in enumerate(fruits):
    print(index, value)
# Out:
# 0 apple
# 1 banana
# 2 mango

# %%
fruits = ["", "", "apple"]
print(any(fruits))
# Out:
# True

# %%
fruits = ["", "", ""]
print(any(fruits))
# Out:
# False

# %%
mylist = ['one' , 'two' , 'three' , 'four' , 'five' , 'six' , 'seven' , 'eight']

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist[0:3] # Return all items from 0th to 3rd index location excluding the item
# Out:
# ['one', 'two', 'three']

# %%
mylist[2:5] # List all items from 2nd to 5th index location excluding the item a
# Out:
# ['three', 'four', 'five']

# %%
mylist[:3] # Return first three items
# Out:
# ['one', 'two', 'three']

# %%
mylist[:2] # Return first two items
# Out:
# ['one', 'two']

# %%
mylist[-3:] # Return last three items
# Out:
# ['six', 'seven', 'eight']

# %%
mylist[-2:] # Return last two items
# Out:
# ['seven', 'eight']

# %%
mylist[-1] # Return last item of the list
# Out:
# 'eight'

# %%
mylist[:] # Return whole list
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# ## Add , Remove & Change Items

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist.append('nine') # Add an item to the end of the list 
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist.insert(9,'ten') # Add item at index location 9 
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
mylist.insert(1,'ONE') # Add item at index location 1 
mylist
# Out:
# ['one',
#  'ONE',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten']

# %%
mylist.remove('ONE') # Remove item "ONE" 
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
mylist.pop() # Remove last item of the list 
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist.pop(8) # Remove item at index location 8 
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
del mylist[7] # Remove item at index location 7 
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven']

# %%
   # Change value of the string 

mylist[0] = 1 
mylist[1] = 2 
mylist[2] = 3 
mylist
# Out:
# [1, 2, 3, 'four', 'five', 'six', 'seven']

# %%
mylist.clear() # Empty List / Delete all items in the list 
mylist
# Out:
# []

# %%
del mylist # Delete the whole list 
mylist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 del mylist # Delete the whole list
# ----> 2 mylist
#
# NameError: name 'mylist' is not defined

# %% [markdown]
# ## Copy List

# %%
mylist = ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine' ]

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist1 = mylist # Create a new reference "mylist1"

# %%
mylist1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
id(mylist) , id(mylist1) # The address of both mylist & mylist1 will be the same
# Out:
# (2123137798208, 2123137798208)

# %%
mylist2 = mylist.copy() # Create a copy of the list

# %%
mylist2
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
id(mylist2) # The address of mylist2 will be different from mylist because mylis
# Out:
# 2123131642240

# %%
mylist[0] = 1

# %%
mylist
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist1 # mylist1 will be also impacted as it is pointing to the same list
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist2 # Copy of list won't be impacted due to changes made on the original lis
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %% [markdown]
# ## Join Lists

# %%
list1 = ['one', 'two', 'three', 'four'] 
list2 = ['five', 'six', 'seven', 'eight']

# %%
list1
# Out:
# ['one', 'two', 'three', 'four']

# %%
list2
# Out:
# ['five', 'six', 'seven', 'eight']

# %%
list3 = list1 + list2 # Join two lists by '+' operator 
list3
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.extend(list2) #Append list2 with list1 
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# ## List Membership

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
'one' in list1 # Check if 'one' exist in the list
# Out:
# True

# %%
'ten' in list1 # Check if 'ten' exist in the list
# Out:
# False

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
if 'three' in list1:   # Check if 'three' exist in the list 
 print('Three is present in the list') 
else: 
 print('Three is not present in the list')
# Out:
# Three is present in the list

# %%
if 'eleven' in list1: # Check if 'eleven' exist in the list 
 print('eleven is present in the list') 
else: 
 print('eleven is not present in the list')
# Out:
# eleven is not present in the list

# %% [markdown]
# ## Reverse & Sort List

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.reverse()              # Reverse the list 
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1 = list1[::-1]           # Reverse the list 
list1
# Out:
# ['eight', 'seven', 'six', 'five', 'four', 'three', 'two', 'one']

# %%
mylist3 = [9,5,2,99,12,88,34] 
mylist3.sort()                          # Sort list in ascending order 
mylist3
# Out:
# [2, 5, 9, 12, 34, 88, 99]

# %%
mylist3 = [9,5,2,99,12,88,34] 
mylist3.sort(reverse=True) # Sort list in descending order 
mylist3
# Out:
# [99, 88, 34, 12, 9, 5, 2]

# %%
mylist4 = [88,65,33,21,11,98] 
sorted(mylist4) # Returns a new sorted list and doesn't change original l
# Out:
# [11, 21, 33, 65, 88, 98]

# %%
mylist4
# Out:
# [88, 65, 33, 21, 11, 98]

# %% [markdown]
# ## Loop through a list

# %%
list1
# Out:
# ['eight', 'seven', 'six', 'five', 'four', 'three', 'two', 'one']

# %%
for i in list1: 
 print(i)
# Out:
# eight
# seven
# six
# five
# four
# three
# two
# one

# %%
for i in enumerate(list1): 
 print(i)
# Out:
# (0, 'eight')
# (1, 'seven')
# (2, 'six')
# (3, 'five')
# (4, 'four')
# (5, 'three')
# (6, 'two')
# (7, 'one')

# %% [markdown]
# ## Count

# %%
list10 =['one', 'two', 'three', 'four', 'one', 'one', 'two', 'three']

# %%
list10
# Out:
# ['one', 'two', 'three', 'four', 'one', 'one', 'two', 'three']

# %%
list10.count('one') # Number of times item "one" occurred in the list.
# Out:
# 3

# %%
list10.count('two') # Occurence of item 'two' in the list
# Out:
# 2

# %%
list10.count('four') #Occurence of item 'four' in the list
# Out:
# 1

# %% [markdown]
# ## All / Any
#
#         # The all() method returns:
#
#         # True - If all elements in a list are true
#         # False - If any element in a list is false
#
#         # The any() function returns True if any element in the list is True. If not, any() returns False.

# %%
L1 = [1,2,3,4,0]

# %%
L1
# Out:
# [1, 2, 3, 4, 0]

# %%
all(L1)    # Will Return false as one value is false (Value 0)
# Out:
# False

# %%
any(L1)   # Will Return True as we have items in the list with True value
# Out:
# True

# %%
L2 = [1,2,3,4,True,False]

# %%
L2
# Out:
# [1, 2, 3, 4, True, False]

# %%
all(L2)    # Returns false as one value is false
# Out:
# False

# %%
any(L2)   # Will Return True as we have items in the list with True value
# Out:
# True

# %%
L3 = [1,2,3,True]

# %%
L3
# Out:
# [1, 2, 3, True]

# %%
all(L3) # Will return True as all items in the list are True
# Out:
# True

# %%
txt = " abc def ghi " 
 
txt.lstrip()
# Out:
# 'abc def ghi '

# %%
txt = " abc def ghi " 
 
txt.strip()
# Out:
# 'abc def ghi'

# %% [markdown]
# ## Using Escape Character

# %%
#Using double quotes in the string is not allowed. 
mystr = "My favourite TV Series is "Game of Thrones""
# Out:
#   Cell In[90], line 2
#     mystr = "My favourite TV Series is "Game of Thrones""
#                                         ^
# SyntaxError: invalid syntax

# %%
#Using escape character to allow illegal characters 
mystr = "My favourite series is \"Game of Thrones\"" 
print(mystr)
# Out:
# My favourite series is "Game of Thrones"
